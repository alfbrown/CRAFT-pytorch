# %% [markdown]
# <a href="https://colab.research.google.com/github/alfbrown/CRAFT-pytorch/blob/master/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("claims.csv")
x= df.columns.to_list()
x
# Out:
# ['Id',
#  'PATIENTID',
#  'PROVIDERID',
#  'PRIMARYPATIENTINSURANCEID',
#  'SECONDARYPATIENTINSURANCEID',
#  'DEPARTMENTID',
#  'PATIENTDEPARTMENTID',
#  'DIAGNOSIS1',
#  'DIAGNOSIS2',
#  'DIAGNOSIS3',
#  'DIAGNOSIS4',
#  'DIAGNOSIS5',
#  'DIAGNOSIS6',
#  'DIAGNOSIS7',
#  'DIAGNOSIS8',
#  'REFERRINGPROVIDERID',
#  'APPOINTMENTID',
#  'CURRENTILLNESSDATE',
#  'SERVICEDATE',
#  'SUPERVISINGPROVIDERID',
#  'STATUS1',
#  'STATUS2',
#  'STATUSP',
#  'OUTSTANDING1',
#  'OUTSTANDING2',
#  'OUTSTANDINGP',
#  'LASTBILLEDDATE1',
#  'LASTBILLEDDATE2',
#  'LASTBILLEDDATEP',
#  'HEALTHCARECLAIMTYPEID1',
#  'HEALTHCARECLAIMTYPEID2']

# %%
list = {'object': 'string','int64':'number', 'float64':'number'}

# %%
df = pd.read_csv("claims.csv")
test = pd.DataFrame(df.dtypes).reset_index()
test.columns = ['field', 'dtype']
test.replace(list)
# Out:
#                           field   dtype
# 0                            Id  string
# 1                     PATIENTID  string
# 2                    PROVIDERID  string
# 3     PRIMARYPATIENTINSURANCEID  string
# 4   SECONDARYPATIENTINSURANCEID  string
# 5                  DEPARTMENTID  number
# 6           PATIENTDEPARTMENTID  number
# 7                    DIAGNOSIS1  number
# 8                    DIAGNOSIS2  number
# 9                    DIAGNOSIS3  number
# 10                   DIAGNOSIS4  number
# 11                   DIAGNOSIS5  number
# 12                   DIAGNOSIS6  number
# 13                   DIAGNOSIS7  number
# 14                   DIAGNOSIS8  number
# 15          REFERRINGPROVIDERID  number
# 16                APPOINTMENTID  string
# 17           CURRENTILLNESSDATE  string
# 18                  SERVICEDATE  string
# 19        SUPERVISINGPROVIDERID  string
# 20                      STATUS1  string
# 21                      STATUS2  string
# ...

# %%
test
# Out:
#                                    0
# Id                            object
# PATIENTID                     object
# PROVIDERID                    object
# PRIMARYPATIENTINSURANCEID     object
# SECONDARYPATIENTINSURANCEID   object
# DEPARTMENTID                   int64
# PATIENTDEPARTMENTID            int64
# DIAGNOSIS1                     int64
# DIAGNOSIS2                   float64
# DIAGNOSIS3                   float64
# DIAGNOSIS4                   float64
# DIAGNOSIS5                   float64
# DIAGNOSIS6                   float64
# DIAGNOSIS7                   float64
# DIAGNOSIS8                   float64
# REFERRINGPROVIDERID          float64
# APPOINTMENTID                 object
# CURRENTILLNESSDATE            object
# SERVICEDATE                   object
# SUPERVISINGPROVIDERID         object
# STATUS1                       object
# STATUS2                       object
# STATUSP                       object
# OUTSTANDING1                 float64
# ...

# %%
test2 = test[0].to_list()
test2
# Out:
# [dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('int64')]

# %%
x2 = df.dtypes(lambda)
x2
# Out:
# Id                              object
# PATIENTID                       object
# PROVIDERID                      object
# PRIMARYPATIENTINSURANCEID       object
# SECONDARYPATIENTINSURANCEID     object
# DEPARTMENTID                     int64
# PATIENTDEPARTMENTID              int64
# DIAGNOSIS1                       int64
# DIAGNOSIS2                     float64
# DIAGNOSIS3                     float64
# DIAGNOSIS4                     float64
# DIAGNOSIS5                     float64
# DIAGNOSIS6                     float64
# DIAGNOSIS7                     float64
# DIAGNOSIS8                     float64
# REFERRINGPROVIDERID            float64
# APPOINTMENTID                   object
# CURRENTILLNESSDATE              object
# SERVICEDATE                     object
# SUPERVISINGPROVIDERID           object
# STATUS1                         object
# STATUS2                         object
# STATUSP                         object
# OUTSTANDING1                   float64
# ...

# %%
for i in x:
    #print(i)
    string = f'dimensions: \n  - name: {i} \n  - sql: {i} \n  - type: string'
    #name = f'- name: {i} if this works'
    print(string)
# Out:
# dimensions:
#   - name: Id
#   - sql: Id
#   - type: string
# dimensions:
#   - name: PATIENTID
#   - sql: PATIENTID
#   - type: string
# dimensions:
#   - name: PROVIDERID
#   - sql: PROVIDERID
#   - type: string
# dimensions:
#   - name: PRIMARYPATIENTINSURANCEID
#   - sql: PRIMARYPATIENTINSURANCEID
#   - type: string
# dimensions:
#   - name: SECONDARYPATIENTINSURANCEID
#   - sql: SECONDARYPATIENTINSURANCEID
#   - type: string
# dimensions:
#   - name: DEPARTMENTID
#   - sql: DEPARTMENTID
#   - type: string
# dimensions:
#   - name: PATIENTDEPARTMENTID
#   - sql: PATIENTDEPARTMENTID
#   - type: string
# dimensions:
#   - name: DIAGNOSIS1
#   - sql: DIAGNOSIS1
#   - type: string
# dimensions:
#   - name: DIAGNOSIS2
#   - sql: DIAGNOSIS2
#   - type: string
# dimensions:
#   - name: DIAGNOSIS3
#   - sql: DIAGNOSIS3
#   - type: string
# dimensions:
#   - name: DIAGNOSIS4
#   - sql: DIAGNOSIS4
#   - type: string
# dimensions:
#   - name: DIAGNOSIS5
#   - sql: DIAGNOSIS5
# ...

# %%
L = ["This is Delhi \n", "This is Paris \n", "This is London \n"]
print(L)
# Out:
# ['This is Delhi \n', 'This is Paris \n', 'This is London \n']

# %%
def create_import_structure(file):
    #df = pd.read_csv(file)
